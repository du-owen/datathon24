# %%
import os
import pandas as pd
from PIL import Image
import ast
import sys

# %%
## Paths

# %%
image_folder = "images/images"  # Folder containing your images
label_folder = "first10k/kaggle/working/yolov5_train/detect_test/labels"  # Folder containing your bounding box text files
csv_path = "train.csv"    # Path to your CSV file

# Load the CSV file
df = pd.read_csv(csv_path)

# %%
counter = 0
for _, row in df.iterrows():
    filename = row['filename']  # e.g. 'chart_0.png'
    image_path = os.path.join(image_folder, filename)
    label_path = os.path.join(label_folder, filename.replace('.png', '.txt'))
    # Read the bounding box from the corresponding text file
    try:
        with open(label_path, 'r') as f:
            bbox_data = f.readline().strip()
    except FileNotFoundError:
        # If the label file does not exist, skip this image
        print(f"Label file not found for {filename}. Skipping.")
        cropped_image = img
        new_image_path = os.path.join("cropped_images", filename)
        cropped_image.save(new_image_path)
        continue
    bbox = list(map(float, bbox_data.split()[1:]))  # [x_center, y_center, width, height]

    if len(bbox) != 4:
        print(f"Label file for {filename} has more than one box or incorrect format. Skipping.")
        cropped_image = img
        new_image_path = os.path.join("cropped_images", filename)
        cropped_image.save(new_image_path)
        continue
    # Calculate the box coordinates for cropping
    x_center, y_center, width, height = bbox
    img = Image.open(image_path)
    img_width, img_height = img.size

    # Convert YOLO coordinates to PIL coordinates
    x_min = int((x_center - width / 2) * img_width)
    x_max = int((x_center + width / 2) * img_width)
    y_min = int((y_center - height / 2) * img_height)
    y_max = int((y_center + height / 2) * img_height)

    # Crop the image
    cropped_image = img.crop((x_min, y_min, x_max, y_max))
    new_image_path = os.path.join("cropped_images", filename)
    cropped_image.save(new_image_path)
    # Get the new offset due to cropping
    x_offset = x_min
    y_offset = y_min

    # Adjust the box coordinates in the CSV file
    boxes_str = row['boxes']
    boxes = ast.literal_eval(boxes_str)

    # Update the coordinates considering the offset due to cropping
    new_boxes = []
    for box in boxes:
        new_box = [
            box[i] - (x_offset if i % 2 == 0 else y_offset)
            for i in range(len(box))
        ]
        new_boxes.append(new_box)
    # Update the CSV with the new box coordinates
    df.loc[_, 'boxes'] = str(new_boxes)

# Save the updated CSV
df.to_csv("updated_data.csv", index=False)

# %% [markdown]
# ## Validation Cropping

# %%
image_folder = "images/images"  # Folder containing your images
label_folder = "val10k/kaggle/working/yolov5_train/detect_test/labels"  # Folder containing your bounding box text files
csv_path = "updated_data.csv"    # Path to your CSV file

# %%
for i in range(10000, 20000):
    filename = "chart_" + str(i) + ".png"
    image_path = os.path.join(image_folder, filename)
    label_path = os.path.join(label_folder, filename.replace('.png', '.txt'))
    # Read the bounding box from the corresponding text file

    try:
        with open(label_path, 'r') as f:
            bbox_data = f.readline().strip()
    except FileNotFoundError:
        # If the label file does not exist, skip this image
        print(f"Label file not found for {filename}. Skipping.")
        cropped_image = img
        new_image_path = os.path.join("cropped_images", filename)
        cropped_image.save(new_image_path)
        continue

    bbox = list(map(float, bbox_data.split()[1:]))  # [x_center, y_center, width, height]

    if len(bbox) != 4:
        print(f"Label file for {filename} has more than one box or incorrect format. Skipping.")
        cropped_image = img
        new_image_path = os.path.join("cropped_images", filename)
        cropped_image.save(new_image_path)
        continue
    # Calculate the box coordinates for cropping
    x_center, y_center, width, height = bbox
    img = Image.open(image_path)
    img_width, img_height = img.size

    # Convert YOLO coordinates to PIL coordinates
    x_min = int((x_center - width / 2) * img_width)
    x_max = int((x_center + width / 2) * img_width)
    y_min = int((y_center - height / 2) * img_height)
    y_max = int((y_center + height / 2) * img_height)

    # Crop the image
    cropped_image = img.crop((x_min, y_min, x_max, y_max))
    new_image_path = os.path.join("cropped_images", filename)
    cropped_image.save(new_image_path)
    # Get the new offset due to cropping
    '''
    x_offset = x_min
    y_offset = y_min

    # Adjust the box coordinates in the CSV file
    boxes_str = row['boxes']
    boxes = ast.literal_eval(boxes_str)

    # Update the coordinates considering the offset due to cropping
    new_boxes = []
    for box in boxes:
        new_box = [
            box[i] - (x_offset if i % 2 == 0 else y_offset)
            for i in range(len(box))
        ]
        new_boxes.append(new_box)
    # Update the CSV with the new box coordinates
    df.loc[_, 'boxes'] = str(new_boxes)
    '''

# Save the updated CSV
#df.to_csv("updated_data.csv", index=False)
# Out:
# Label file not found for chart_10423.png. Skipping.
# Label file not found for chart_11893.png. Skipping.
# Label file not found for chart_11894.png. Skipping.
# Label file not found for chart_11895.png. Skipping.
# Label file not found for chart_13326.png. Skipping.
# Label file not found for chart_14351.png. Skipping.
# Label file not found for chart_14496.png. Skipping.
# Label file not found for chart_18136.png. Skipping.
# Label file not found for chart_18138.png. Skipping.
# Label file not found for chart_18194.png. Skipping.
# Label file not found for chart_18253.png. Skipping.
# Label file not found for chart_18486.png. Skipping.
# Label file not found for chart_18487.png. Skipping.
# Label file not found for chart_18488.png. Skipping.
# Label file not found for chart_18489.png. Skipping.
# Label file not found for chart_18614.png. Skipping.
# Label file not found for chart_18617.png. Skipping.
# Label file not found for chart_18618.png. Skipping.
# Label file not found for chart_18692.png. Skipping.

# %% [markdown]
# ## Test cropping

# %%
image_folder = "images/images"  # Folder containing your images
label_folder = "test10k/kaggle/working/yolov5_train/detect_test2/labels"  # Folder containing your bounding box text files
csv_path = "updated_data.csv"    # Path to your CSV file

# %%
for i in range(20000, 30000):
    filename = "chart_" + str(i) + ".png"
    image_path = os.path.join(image_folder, filename)
    label_path = os.path.join(label_folder, filename.replace('.png', '.txt'))
    # Read the bounding box from the corresponding text file
    print(label_path)
    try:
        with open(label_path, 'r') as f:
            bbox_data = f.readline().strip()
    except FileNotFoundError:
        # If the label file does not exist, skip this image
        print(f"Label file not found for {filename}. Skipping.")
        cropped_image = img
        new_image_path = os.path.join("cropped_images_test", filename)
        cropped_image.save(new_image_path)
        continue

    bbox = list(map(float, bbox_data.split()[1:]))  # [x_center, y_center, width, height]

    if len(bbox) != 4:
        print(f"Label file for {filename} has more than one box or incorrect format. Skipping.")
        cropped_image = img
        new_image_path = os.path.join("cropped_images_test", filename)
        cropped_image.save(new_image_path)
        continue
    # Calculate the box coordinates for cropping
    x_center, y_center, width, height = bbox
    img = Image.open(image_path)
    img_width, img_height = img.size

    # Convert YOLO coordinates to PIL coordinates
    x_min = int((x_center - width / 2) * img_width)
    x_max = int((x_center + width / 2) * img_width)
    y_min = int((y_center - height / 2) * img_height)
    y_max = int((y_center + height / 2) * img_height)

    # Crop the image
    cropped_image = img.crop((x_min, y_min, x_max, y_max))
    new_image_path = os.path.join("cropped_images_test", filename)
    cropped_image.save(new_image_path)
    # Get the new offset due to cropping
    '''
    x_offset = x_min
    y_offset = y_min

    # Adjust the box coordinates in the CSV file
    boxes_str = row['boxes']
    boxes = ast.literal_eval(boxes_str)

    # Update the coordinates considering the offset due to cropping
    new_boxes = []
    for box in boxes:
        new_box = [
            box[i] - (x_offset if i % 2 == 0 else y_offset)
            for i in range(len(box))
        ]
        new_boxes.append(new_box)
    # Update the CSV with the new box coordinates
    df.loc[_, 'boxes'] = str(new_boxes)
    '''

# Save the updated CSV
#df.to_csv("updated_data.csv", index=False)
# Out:
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20000.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20001.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20002.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20003.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20004.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20005.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20006.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20007.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20008.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20009.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20010.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20011.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20012.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20013.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20014.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20015.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20016.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20017.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20018.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20019.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20020.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20021.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20022.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20023.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20024.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20025.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20026.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20027.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20028.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20029.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20030.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20031.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20032.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20033.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20034.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20035.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20036.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20037.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20038.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20039.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20040.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20041.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20042.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20043.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20044.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20045.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20046.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20047.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20048.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20049.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20050.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20051.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20052.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20053.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20054.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20055.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20056.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20057.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20058.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20059.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20060.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20061.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20062.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20063.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20064.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20065.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20066.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20067.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20068.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20069.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20070.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20071.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20072.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20073.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20074.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20075.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20076.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20077.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20078.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20079.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20080.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20081.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20082.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20083.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20084.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20085.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20086.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20087.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20088.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20089.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20090.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20091.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20092.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20093.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20094.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20095.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20096.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20097.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20098.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20099.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20100.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20101.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20102.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20103.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20104.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20105.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20106.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20107.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20108.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20109.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20110.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20111.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20112.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20113.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20114.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20115.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20116.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20117.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20118.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20119.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20120.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20121.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20122.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20123.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20124.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20125.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20126.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20127.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20128.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20129.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20130.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20131.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20132.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20133.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20134.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20135.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20136.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20137.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20138.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20139.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20140.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20141.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20142.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20143.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20144.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20145.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20146.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20147.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20148.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20149.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20150.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20151.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20152.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20153.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20154.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20155.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20156.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20157.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20158.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20159.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20160.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20161.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20162.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20163.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20164.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20165.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20166.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20167.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20168.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20169.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20170.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20171.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20172.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20173.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20174.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20175.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20176.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20177.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20178.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20179.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20180.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20181.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20182.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20183.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20184.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20185.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20186.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20187.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20188.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20189.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20190.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20191.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20192.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20193.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20194.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20195.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20196.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20197.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20198.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20199.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20200.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20201.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20202.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20203.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20204.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20205.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20206.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20207.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20208.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20209.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20210.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20211.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20212.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20213.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20214.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20215.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20216.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20217.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20218.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20219.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20220.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20221.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20222.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20223.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20224.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20225.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20226.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20227.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20228.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20229.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20230.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20231.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20232.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20233.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20234.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20235.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20236.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20237.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20238.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20239.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20240.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20241.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20242.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20243.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20244.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20245.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20246.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20247.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20248.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20249.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20250.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20251.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20252.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20253.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20254.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20255.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20256.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20257.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20258.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20259.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20260.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20261.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20262.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20263.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20264.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20265.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20266.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20267.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20268.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20269.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20270.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20271.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20272.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20273.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20274.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20275.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20276.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20277.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20278.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20279.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20280.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20281.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20282.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20283.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20284.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20285.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20286.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20287.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20288.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20289.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20290.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20291.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20292.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20293.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20294.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20295.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20296.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20297.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20298.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20299.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20300.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20301.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20302.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20303.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20304.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20305.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20306.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20307.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20308.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20309.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20310.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20311.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20312.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20313.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20314.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20315.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20316.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20317.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20318.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20319.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20320.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20321.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_20322.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_
txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29834.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29835.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29836.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29837.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29838.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29839.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29840.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29841.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29842.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29843.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29844.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29845.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29846.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29847.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29848.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29849.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29850.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29851.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29852.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29853.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29854.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29855.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29856.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29857.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29858.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29859.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29860.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29861.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29862.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29863.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29864.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29865.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29866.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29867.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29868.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29869.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29870.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29871.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29872.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29873.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29874.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29875.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29876.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29877.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29878.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29879.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29880.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29881.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29882.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29883.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29884.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29885.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29886.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29887.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29888.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29889.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29890.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29891.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29892.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29893.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29894.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29895.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29896.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29897.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29898.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29899.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29900.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29901.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29902.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29903.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29904.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29905.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29906.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29907.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29908.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29909.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29910.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29911.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29912.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29913.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29914.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29915.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29916.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29917.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29918.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29919.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29920.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29921.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29922.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29923.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29924.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29925.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29926.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29927.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29928.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29929.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29930.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29931.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29932.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29933.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29934.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29935.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29936.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29937.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29938.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29939.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29940.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29941.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29942.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29943.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29944.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29945.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29946.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29947.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29948.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29949.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29950.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29951.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29952.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29953.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29954.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29955.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29956.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29957.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29958.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29959.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29960.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29961.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29962.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29963.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29964.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29965.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29966.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29967.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29968.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29969.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29970.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29971.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29972.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29973.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29974.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29975.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29976.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29977.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29978.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29979.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29980.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29981.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29982.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29983.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29984.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29985.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29986.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29987.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29988.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29989.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29990.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29991.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29992.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29993.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29994.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29995.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29996.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29997.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29998.txt
# test10k/kaggle/working/yolov5_train/detect_test2/labels\chart_29999.txt

# %% [markdown]
# ## Vizualizing results

# %%
import ast
import matplotlib.pyplot as plt
from PIL import Image

# Correct image path
image_path = 'cropped_images_train/chart_8.png'  # Change this to a valid path
image = Image.open(image_path)  # Opening the image file

# Proper list parsing
first_row_list = [
    [40, 7, 76, 45, 40, 43], [76, 45, 30, 78, 40, 43], [30, 78, 27, 77, 40, 43], [27, 77, 9, 24, 40, 43], [9, 24, 31, 8, 40, 43], [31, 8, 39, 7, 40, 43], [39, 7, 40, 7, 40, 43]
]  # This can be directly initialized without ast.literal_eval

# Extract x and y coordinates
x_coords = []
y_coords = []
for sub_list in first_row_list:
    for i in range(0, len(sub_list), 2):  # Step by 2 to get pairs of coordinates
        x_coords.append(sub_list[i])  # Append x coordinate
        y_coords.append(sub_list[i + 1])  # Append y coordinate

# Plotting
plt.imshow(image)  # Display the image
plt.scatter(x_coords, y_coords, color='red', marker='x', s=100)  # Plot the points with red 'x' markers
plt.title('Points on Image')
plt.show()  # Display the plot
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [68], line 7
#       5 # Correct image path
#       6 image_path = 'cropped_images_train/chart_8.png'  # Change this to a valid path
# ----> 7 image = Image.open(image_path)  # Opening the image file
#       9 # Proper list parsing
#      10 first_row_list = [
#      11     [40, 7, 76, 45, 40, 43], [76, 45, 30, 78, 40, 43], [30, 78, 27, 77, 40, 43], [27, 77, 9, 24, 40, 43], [9, 24, 31, 8, 40, 43], [31, 8, 39, 7, 40, 43], [39, 7, 40, 7, 40, 43]
#      12 ]  # This can be directly initialized without ast.literal_eval
#
# File c:\users\phili\appdata\local\programs\python\python39\lib\site-packages\PIL\Image.py:3218, in open(fp, mode, formats)
#    3215     filename = fp
#    3217 if filename:
# -> 3218     fp = builtins.open(filename, "rb")
#    3219     exclusive_fp = True
#    3221 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cropped_images_train/chart_8.png'
